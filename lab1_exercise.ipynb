# %% [markdown]
# # COMP534 Lab 1 Exercise
#
# After we learn some python libraries, like Pandas, Matplotlib, and Seaborn, we can do some exercises abased on these libraries.

# %% [markdown]
# Solutuins
#
# https://github.com/candreop/COMP534

# %% [markdown]
# ## Exercise 1
# Different from the toy dataset, we can download the iris dataset from the [website](https://www.kaggle.com/datasets/himanshunakrani/iris-dataset) or you can find the dataset on Lab 1 folder.
#
# To upload your dataset to Google Colab, click on `Files` in the left-hand menu and then `Upload`:
#
# ![image.png](data:image/png;base64,...)
#
# Here is what you will have to do:
#
#  - 1: Load the dataset into a DataFrame;
#  - 2: Print the dataset information;
#  - 3: Print the first 10 rows/samples;
#  - 4: Print the dataset index
#  - 5: Print the dataset columns
#  - 6: Output the special attributes of dataset, like 'species', 'sepal_length' ...
#  - 7: Add new column "ID" using dataset index and print the dataset;
#  - 8: Remove the ID column of dataset and print the dataset.

# %%
# !wget https://raw.githubusercontent.com/atanilson/Com634-AppliedAI/main/lab1-iris.csv -O lab1-iris.csv
# Out:
# --2025-10-09 10:43:50--  https://raw.githubusercontent.com/atanilson/Com634-AppliedAI/main/lab1-iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3858 (3.8K) [text/plain]
# Saving to: ‘lab1-iris.csv’
#
# lab1-iris.csv       100%[===================>]   3.77K  --.-KB/s    in 0s
#
# 2025-10-09 10:43:50 (48.5 MB/s) - ‘lab1-iris.csv’ saved [3858/3858]

# %%
# coding here
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv("lab1-iris.csv")

display(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.columns[0:4]
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
iris["ID"] = iris.index

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species   ID
# 0             5.1          3.5           1.4          0.2     setosa    0
# 1             4.9          3.0           1.4          0.2     setosa    1
# 2             4.7          3.2           1.3          0.2     setosa    2
# 3             4.6          3.1           1.5          0.2     setosa    3
# 4             5.0          3.6           1.4          0.2     setosa    4
# ..            ...          ...           ...          ...        ...  ...
# 145           6.7          3.0           5.2          2.3  virginica  145
# 146           6.3          2.5           5.0          1.9  virginica  146
# 147           6.5          3.0           5.2          2.0  virginica  147
# 148           6.2          3.4           5.4          2.3  virginica  148
# 149           5.9          3.0           5.1          1.8  virginica  149
#
# [150 rows x 6 columns]

# %%
iris = iris.drop("ID", axis=1)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Exercise 2
# After we download the dataset, we can visualize the dataset.
# As the dataset includes 3 different species (setosa, virginica and versicolor) with 4 different properties (sepal_length, sepal_width, petal_length, and petal_width), we can visulize any two properties within 3 species. For example, we can plot the scatter figures using the sepal_length as "X"- axe and sepal_width as "Y"- axe, you can observe the relationships between different properties.
#
#  - Plot different scatter figures;
#  - Plot the 3 scatter figures on the same figures;
#  - Set various colors, styles, labels, and axes limits;
#  - Compare each species.

# %%
# coding here
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 3
# Now, we can use library "seaborn" to plot the above figures.
#
#
# After that, we can visualize any property of dataset using Histograms, KDE, and densities.
# - Plot the Histograms of "sepal_length" ...
# - Plot the KDE of "sepal_length" ...
# - Plot the joint distribution of "sepal_length" ...

# %%
# coding here
import seaborn as sns
